# %%
#ViT tiny

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torch.backends.cudnn as cudnn

import torchvision
import torchvision.transforms as transforms

import os

# %%
from transformers import AutoImageProcessor, AutoConfig, AutoModelForImageClassification

# Load the processor (no need to change this as it only handles preprocessing)
processor = AutoImageProcessor.from_pretrained("WinKawaks/vit-tiny-patch16-224")

# Load the configuration
config = AutoConfig.from_pretrained("WinKawaks/vit-tiny-patch16-224")
config.image_size = 128

# Initialize the model with the configuration (without pretrained weights)
model = AutoModelForImageClassification.from_config(config)

# Print the model architecture to verify
print(model)
# Out:
# ViTForImageClassification(
#   (vit): ViTModel(
#     (embeddings): ViTEmbeddings(
#       (patch_embeddings): ViTPatchEmbeddings(
#         (projection): Conv2d(3, 192, kernel_size=(16, 16), stride=(16, 16))
#       )
#       (dropout): Dropout(p=0.0, inplace=False)
#     )
#     (encoder): ViTEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x ViTLayer(
#           (attention): ViTSdpaAttention(
#             (attention): ViTSdpaSelfAttention(
#               (query): Linear(in_features=192, out_features=192, bias=True)
#               (key): Linear(in_features=192, out_features=192, bias=True)
#               (value): Linear(in_features=192, out_features=192, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#             (output): ViTSelfOutput(
#               (dense): Linear(in_features=192, out_features=192, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (intermediate): ViTIntermediate(
#             (dense): Linear(in_features=192, out_features=768, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ViTOutput(
#             (dense): Linear(in_features=768, out_features=192, bias=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#           (layernorm_before): LayerNorm((192,), eps=1e-12, elementwise_affine=True)
#           (layernorm_after): LayerNorm((192,), eps=1e-12, elementwise_affine=True)
#         )
#       )
#     )
#     (layernorm): LayerNorm((192,), eps=1e-12, elementwise_affine=True)
#   )
#   (classifier): Linear(in_features=192, out_features=1000, bias=True)
# )

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
best_acc = 0  # best test accuracy
start_epoch = 0  # start from epoch 0 or last checkpoint epoch

# Data
print('==> Preparing data..')
transform_train = transforms.Compose([
    transforms.Resize((128, 128)),
    transforms.Grayscale(3),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

transform_test = transforms.Compose([
    transforms.Resize((128, 128)),
    transforms.Grayscale(3),
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

trainset = torchvision.datasets.MNIST(root='./data', train=True, download=True, transform=transform_train)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=128, shuffle=True, num_workers=2)

testset = torchvision.datasets.MNIST(root='./data', train=False, download=True, transform=transform_test)
testloader = torch.utils.data.DataLoader(testset, batch_size=100, shuffle=False, num_workers=2)
classes = trainset.classes
# Out:
# ==> Preparing data..

# %%
#view data

import matplotlib.pyplot as plt
import numpy as np

# Helper function for inline image display
def matplotlib_imshow(img, one_channel=False):
    if one_channel:
        img = img.mean(dim=0)
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    if one_channel:
        plt.imshow(npimg, cmap="Greys")
    else:
        plt.imshow(np.transpose(npimg, (1, 2, 0)))

dataiter = iter(trainloader)
images, labels = next(dataiter)

# Create a grid from the images and show them
img_grid = torchvision.utils.make_grid(images, nrow=20)
matplotlib_imshow(img_grid, one_channel=False)
print('  '.join(classes[labels[j]] for j in range(4)))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.71453285..1.8768656].
# 6 - six  7 - seven  0 - zero  9 - nine

# %%
print('==> Building model..')

model = model.to(device)


if device == 'cuda':
    model = torch.nn.DataParallel(model)
    cudnn.benchmark = True



criterion = nn.CrossEntropyLoss()
#criterion = nn.NLLLoss()
optimizer = optim.SGD(model.parameters(), lr=1e-3, momentum=0.9, weight_decay=0)
# Out:
# ==> Building model..

# %%
# Training
def train(epochs):
    model.train()
    for epoch in range(epochs):

        for batch_idx, (data, target) in enumerate(trainloader):
            data, target = data.to(device), target.to(device)
            optimizer.zero_grad()
            output = model(data)
            logits = output.logits
            loss = criterion(logits, target)
            #loss = nn.NLLLoss(output,target)
            loss.backward()

            optimizer.step()
            if batch_idx % 100 == 0:
                done = batch_idx * len(data)
                percentage = 100. * batch_idx / len(trainloader)
                print(f'Train Epoch: {epoch} [{done:5}/{len(trainloader.dataset)} ({percentage:3.0f}%)]  Loss: {loss.item():.6f}')

        test(trainloader)
        test(testloader)


def test(loader):
    model.eval()
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            logits = output.logits
            test_loss += criterion(logits, target).item() # sum up batch loss
            #test_loss += nn.NLLLoss(output, target).item()
            pred = logits.max(1, keepdim=True)[1] # get the index of the max log-probability
            correct += pred.eq(target.data.view_as(pred)).sum().item()

        test_loss /= len(loader.dataset)
        accuracy = 100. * correct / len(loader.dataset)
        print(f'Test set: Average loss: {test_loss:.4f}, Accuracy: {correct}/{len(loader.dataset)} ({accuracy:.2f}%)')
    return accuracy

# %%
train(50)
test(trainloader)
test(testloader)
# Out:
# Train Epoch: 0 [    0/60000 (  0%)]  Loss: 6.935875
# Train Epoch: 0 [12800/60000 ( 21%)]  Loss: 2.276477
# Train Epoch: 0 [25600/60000 ( 43%)]  Loss: 2.214394
# Train Epoch: 0 [38400/60000 ( 64%)]  Loss: 2.121778
# Train Epoch: 0 [51200/60000 ( 85%)]  Loss: 1.923060
# Test set: Average loss: 0.0149, Accuracy: 16522/60000 (27.54%)
# Test set: Average loss: 0.0189, Accuracy: 2713/10000 (27.13%)
# Train Epoch: 1 [    0/60000 (  0%)]  Loss: 1.863574
# Train Epoch: 1 [12800/60000 ( 21%)]  Loss: 1.847342
# Train Epoch: 1 [25600/60000 ( 43%)]  Loss: 1.639934
# Train Epoch: 1 [38400/60000 ( 64%)]  Loss: 1.675079
# Train Epoch: 1 [51200/60000 ( 85%)]  Loss: 1.645010
# Test set: Average loss: 0.0112, Accuracy: 28124/60000 (46.87%)
# Test set: Average loss: 0.0140, Accuracy: 4735/10000 (47.35%)
# Train Epoch: 2 [    0/60000 (  0%)]  Loss: 1.329140
# Train Epoch: 2 [12800/60000 ( 21%)]  Loss: 1.294294
# Train Epoch: 2 [25600/60000 ( 43%)]  Loss: 1.225179
# Train Epoch: 2 [38400/60000 ( 64%)]  Loss: 1.356709
# Train Epoch: 2 [51200/60000 ( 85%)]  Loss: 1.454052
# Test set: Average loss: 0.0093, Accuracy: 34081/60000 (56.80%)
# Test set: Average loss: 0.0117, Accuracy: 5758/10000 (57.58%)
# Train Epoch: 3 [    0/60000 (  0%)]  Loss: 0.992044
# Train Epoch: 3 [12800/60000 ( 21%)]  Loss: 0.927776
# Train Epoch: 3 [25600/60000 ( 43%)]  Loss: 1.150587
# Train Epoch: 3 [38400/60000 ( 64%)]  Loss: 1.259476
# Train Epoch: 3 [51200/60000 ( 85%)]  Loss: 1.084447
# Test set: Average loss: 0.0078, Accuracy: 38680/60000 (64.47%)
# Test set: Average loss: 0.0101, Accuracy: 6362/10000 (63.62%)
# Train Epoch: 4 [    0/60000 (  0%)]  Loss: 0.927658
# Train Epoch: 4 [12800/60000 ( 21%)]  Loss: 0.976903
# Train Epoch: 4 [25600/60000 ( 43%)]  Loss: 1.065439
# Train Epoch: 4 [38400/60000 ( 64%)]  Loss: 0.822407
# Train Epoch: 4 [51200/60000 ( 85%)]  Loss: 1.143239
# Test set: Average loss: 0.0068, Accuracy: 41500/60000 (69.17%)
# Test set: Average loss: 0.0085, Accuracy: 6926/10000 (69.26%)
# Train Epoch: 5 [    0/60000 (  0%)]  Loss: 0.777393
# Train Epoch: 5 [12800/60000 ( 21%)]  Loss: 1.003843
# Train Epoch: 5 [25600/60000 ( 43%)]  Loss: 0.935372
# Train Epoch: 5 [38400/60000 ( 64%)]  Loss: 0.688973
# Train Epoch: 5 [51200/60000 ( 85%)]  Loss: 0.994253
# Test set: Average loss: 0.0062, Accuracy: 42971/60000 (71.62%)
# Test set: Average loss: 0.0078, Accuracy: 7205/10000 (72.05%)
# Train Epoch: 6 [    0/60000 (  0%)]  Loss: 0.715421
# Train Epoch: 6 [12800/60000 ( 21%)]  Loss: 0.857878
# Train Epoch: 6 [25600/60000 ( 43%)]  Loss: 0.807275
# Train Epoch: 6 [38400/60000 ( 64%)]  Loss: 0.708253
# Train Epoch: 6 [51200/60000 ( 85%)]  Loss: 0.833282
# Test set: Average loss: 0.0058, Accuracy: 44219/60000 (73.70%)
# Test set: Average loss: 0.0075, Accuracy: 7395/10000 (73.95%)
# Train Epoch: 7 [    0/60000 (  0%)]  Loss: 0.770088
# Train Epoch: 7 [12800/60000 ( 21%)]  Loss: 0.718291
# Train Epoch: 7 [25600/60000 ( 43%)]  Loss: 0.707018
# Train Epoch: 7 [38400/60000 ( 64%)]  Loss: 0.596312
# Train Epoch: 7 [51200/60000 ( 85%)]  Loss: 0.693324
# Test set: Average loss: 0.0051, Accuracy: 46292/60000 (77.15%)
# Test set: Average loss: 0.0063, Accuracy: 7754/10000 (77.54%)
# Train Epoch: 8 [    0/60000 (  0%)]  Loss: 0.620514
# Train Epoch: 8 [12800/60000 ( 21%)]  Loss: 0.759156
# Train Epoch: 8 [25600/60000 ( 43%)]  Loss: 0.687034
# Train Epoch: 8 [38400/60000 ( 64%)]  Loss: 0.716273
# Train Epoch: 8 [51200/60000 ( 85%)]  Loss: 0.777665
# Test set: Average loss: 0.0051, Accuracy: 46203/60000 (77.00%)
# Test set: Average loss: 0.0062, Accuracy: 7723/10000 (77.23%)
# Train Epoch: 9 [    0/60000 (  0%)]  Loss: 0.726425
# Train Epoch: 9 [12800/60000 ( 21%)]  Loss: 0.771556
# Train Epoch: 9 [25600/60000 ( 43%)]  Loss: 0.612707
# Train Epoch: 9 [38400/60000 ( 64%)]  Loss: 0.371508
# Train Epoch: 9 [51200/60000 ( 85%)]  Loss: 0.512253
# Test set: Average loss: 0.0046, Accuracy: 47721/60000 (79.53%)
# Test set: Average loss: 0.0059, Accuracy: 7923/10000 (79.23%)
# Train Epoch: 10 [    0/60000 (  0%)]  Loss: 0.594373
# Train Epoch: 10 [12800/60000 ( 21%)]  Loss: 0.530443
# Train Epoch: 10 [25600/60000 ( 43%)]  Loss: 0.612148
# Train Epoch: 10 [38400/60000 ( 64%)]  Loss: 0.651881
# Train Epoch: 10 [51200/60000 ( 85%)]  Loss: 0.652783
# Test set: Average loss: 0.0046, Accuracy: 47317/60000 (78.86%)
# Test set: Average loss: 0.0060, Accuracy: 7886/10000 (78.86%)
# Train Epoch: 11 [    0/60000 (  0%)]  Loss: 0.412976
# Train Epoch: 11 [12800/60000 ( 21%)]  Loss: 0.557122
# Train Epoch: 11 [25600/60000 ( 43%)]  Loss: 0.535654
# Train Epoch: 11 [38400/60000 ( 64%)]  Loss: 0.608073
# Train Epoch: 11 [51200/60000 ( 85%)]  Loss: 0.530981
# Test set: Average loss: 0.0043, Accuracy: 48253/60000 (80.42%)
# Test set: Average loss: 0.0053, Accuracy: 8084/10000 (80.84%)
# Train Epoch: 12 [    0/60000 (  0%)]  Loss: 0.578427
# Train Epoch: 12 [12800/60000 ( 21%)]  Loss: 0.412946
# Train Epoch: 12 [25600/60000 ( 43%)]  Loss: 0.494244
# Train Epoch: 12 [38400/60000 ( 64%)]  Loss: 0.464949
# Train Epoch: 12 [51200/60000 ( 85%)]  Loss: 0.545058
# Test set: Average loss: 0.0038, Accuracy: 49618/60000 (82.70%)
# Test set: Average loss: 0.0051, Accuracy: 8175/10000 (81.75%)
# Train Epoch: 13 [    0/60000 (  0%)]  Loss: 0.336232
# Train Epoch: 13 [12800/60000 ( 21%)]  Loss: 0.656907
# Train Epoch: 13 [25600/60000 ( 43%)]  Loss: 0.544919
# Train Epoch: 13 [38400/60000 ( 64%)]  Loss: 0.394950
# Train Epoch: 13 [51200/60000 ( 85%)]  Loss: 0.460097
# Test set: Average loss: 0.0044, Accuracy: 47672/60000 (79.45%)
# Test set: Average loss: 0.0060, Accuracy: 7825/10000 (78.25%)
# Train Epoch: 14 [    0/60000 (  0%)]  Loss: 0.538924
# Train Epoch: 14 [12800/60000 ( 21%)]  Loss: 0.413473
# Train Epoch: 14 [25600/60000 ( 43%)]  Loss: 0.423389
# Train Epoch: 14 [38400/60000 ( 64%)]  Loss: 0.417824
# Train Epoch: 14 [51200/60000 ( 85%)]  Loss: 0.457579
# Test set: Average loss: 0.0035, Accuracy: 50494/60000 (84.16%)
# Test set: Average loss: 0.0046, Accuracy: 8365/10000 (83.65%)
# Train Epoch: 15 [    0/60000 (  0%)]  Loss: 0.424186
# Train Epoch: 15 [12800/60000 ( 21%)]  Loss: 0.574896
# Train Epoch: 15 [25600/60000 ( 43%)]  Loss: 0.453113
# Train Epoch: 15 [38400/60000 ( 64%)]  Loss: 0.430042
# Train Epoch: 15 [51200/60000 ( 85%)]  Loss: 0.505316
# Test set: Average loss: 0.0036, Accuracy: 50308/60000 (83.85%)
# Test set: Average loss: 0.0048, Accuracy: 8265/10000 (82.65%)
# Train Epoch: 16 [    0/60000 (  0%)]  Loss: 0.611352
# Train Epoch: 16 [12800/60000 ( 21%)]  Loss: 0.431017
# Train Epoch: 16 [25600/60000 ( 43%)]  Loss: 0.392587
# Train Epoch: 16 [38400/60000 ( 64%)]  Loss: 0.399061
# Train Epoch: 16 [51200/60000 ( 85%)]  Loss: 0.393724
# Test set: Average loss: 0.0034, Accuracy: 50851/60000 (84.75%)
# Test set: Average loss: 0.0045, Accuracy: 8427/10000 (84.27%)
# Train Epoch: 17 [    0/60000 (  0%)]  Loss: 0.437686
# Train Epoch: 17 [12800/60000 ( 21%)]  Loss: 0.465213
# Train Epoch: 17 [25600/60000 ( 43%)]  Loss: 0.491188
# Train Epoch: 17 [38400/60000 ( 64%)]  Loss: 0.437036
# Train Epoch: 17 [51200/60000 ( 85%)]  Loss: 0.480273
# Test set: Average loss: 0.0030, Accuracy: 51995/60000 (86.66%)
# Test set: Average loss: 0.0042, Accuracy: 8513/10000 (85.13%)
# Train Epoch: 18 [    0/60000 (  0%)]  Loss: 0.355485
# Train Epoch: 18 [12800/60000 ( 21%)]  Loss: 0.549757
# Train Epoch: 18 [25600/60000 ( 43%)]  Loss: 0.492857
# Train Epoch: 18 [38400/60000 ( 64%)]  Loss: 0.399543
# Train Epoch: 18 [51200/60000 ( 85%)]  Loss: 0.370556
# Test set: Average loss: 0.0029, Accuracy: 52316/60000 (87.19%)
# Test set: Average loss: 0.0039, Accuracy: 8642/10000 (86.42%)
# Train Epoch: 19 [    0/60000 (  0%)]  Loss: 0.341877
# Train Epoch: 19 [12800/60000 ( 21%)]  Loss: 0.311350
# Train Epoch: 19 [25600/60000 ( 43%)]  Loss: 0.302181
# Train Epoch: 19 [38400/60000 ( 64%)]  Loss: 0.345587
# Train Epoch: 19 [51200/60000 ( 85%)]  Loss: 0.475899
# Test set: Average loss: 0.0028, Accuracy: 52788/60000 (87.98%)
# Test set: Average loss: 0.0039, Accuracy: 8671/10000 (86.71%)
# Train Epoch: 20 [    0/60000 (  0%)]  Loss: 0.360830
# Train Epoch: 20 [12800/60000 ( 21%)]  Loss: 0.387530
# Train Epoch: 20 [25600/60000 ( 43%)]  Loss: 0.453497
# Train Epoch: 20 [38400/60000 ( 64%)]  Loss: 0.236899
# Train Epoch: 20 [51200/60000 ( 85%)]  Loss: 0.356379
# Test set: Average loss: 0.0028, Accuracy: 52524/60000 (87.54%)
# Test set: Average loss: 0.0039, Accuracy: 8624/10000 (86.24%)
# Train Epoch: 21 [    0/60000 (  0%)]  Loss: 0.325913
# Train Epoch: 21 [12800/60000 ( 21%)]  Loss: 0.375517
# Train Epoch: 21 [25600/60000 ( 43%)]  Loss: 0.225205
# Train Epoch: 21 [38400/60000 ( 64%)]  Loss: 0.514187
# Train Epoch: 21 [51200/60000 ( 85%)]  Loss: 0.288669
# Test set: Average loss: 0.0027, Accuracy: 52635/60000 (87.72%)
# Test set: Average loss: 0.0037, Accuracy: 8717/10000 (87.17%)
# Train Epoch: 22 [    0/60000 (  0%)]  Loss: 0.427909
# Train Epoch: 22 [12800/60000 ( 21%)]  Loss: 0.342464
# Train Epoch: 22 [25600/60000 ( 43%)]  Loss: 0.269989
# Train Epoch: 22 [38400/60000 ( 64%)]  Loss: 0.231228
# Train Epoch: 22 [51200/60000 ( 85%)]  Loss: 0.299628
# Test set: Average loss: 0.0026, Accuracy: 53205/60000 (88.67%)
# Test set: Average loss: 0.0037, Accuracy: 8741/10000 (87.41%)
# Train Epoch: 23 [    0/60000 (  0%)]  Loss: 0.292516
# Train Epoch: 23 [12800/60000 ( 21%)]  Loss: 0.235949
# Train Epoch: 23 [25600/60000 ( 43%)]  Loss: 0.413209
# Train Epoch: 23 [38400/60000 ( 64%)]  Loss: 0.318666
# Train Epoch: 23 [51200/60000 ( 85%)]  Loss: 0.510802
# Test set: Average loss: 0.0028, Accuracy: 52459/60000 (87.43%)
# Test set: Average loss: 0.0035, Accuracy: 8788/10000 (87.88%)
# Train Epoch: 24 [    0/60000 (  0%)]  Loss: 0.369002
# Train Epoch: 24 [12800/60000 ( 21%)]  Loss: 0.261769
# Train Epoch: 24 [25600/60000 ( 43%)]  Loss: 0.332331
# Train Epoch: 24 [38400/60000 ( 64%)]  Loss: 0.479631
# Train Epoch: 24 [51200/60000 ( 85%)]  Loss: 0.235844
# Test set: Average loss: 0.0024, Accuracy: 53475/60000 (89.12%)
# Test set: Average loss: 0.0031, Accuracy: 8962/10000 (89.62%)
# Train Epoch: 25 [    0/60000 (  0%)]  Loss: 0.323824
# Train Epoch: 25 [12800/60000 ( 21%)]  Loss: 0.292074
# Train Epoch: 25 [25600/60000 ( 43%)]  Loss: 0.297399
# Train Epoch: 25 [38400/60000 ( 64%)]  Loss: 0.238911
# Train Epoch: 25 [51200/60000 ( 85%)]  Loss: 0.375525
# Test set: Average loss: 0.0023, Accuracy: 53841/60000 (89.73%)
# Test set: Average loss: 0.0032, Accuracy: 8922/10000 (89.22%)
# Train Epoch: 26 [    0/60000 (  0%)]  Loss: 0.335628
# Train Epoch: 26 [12800/60000 ( 21%)]  Loss: 0.296972
# Train Epoch: 26 [25600/60000 ( 43%)]  Loss: 0.348127
# Train Epoch: 26 [38400/60000 ( 64%)]  Loss: 0.283869
# Train Epoch: 26 [51200/60000 ( 85%)]  Loss: 0.346383
# Test set: Average loss: 0.0021, Accuracy: 54733/60000 (91.22%)
# Test set: Average loss: 0.0029, Accuracy: 9007/10000 (90.07%)
# Train Epoch: 27 [    0/60000 (  0%)]  Loss: 0.315205
# Train Epoch: 27 [12800/60000 ( 21%)]  Loss: 0.298169
# Train Epoch: 27 [25600/60000 ( 43%)]  Loss: 0.333234
# Train Epoch: 27 [38400/60000 ( 64%)]  Loss: 0.331999
# Train Epoch: 27 [51200/60000 ( 85%)]  Loss: 0.199796
# Test set: Average loss: 0.0020, Accuracy: 54680/60000 (91.13%)
# Test set: Average loss: 0.0031, Accuracy: 8949/10000 (89.49%)
# Train Epoch: 28 [    0/60000 (  0%)]  Loss: 0.148127
# Train Epoch: 28 [12800/60000 ( 21%)]  Loss: 0.203111
# Train Epoch: 28 [25600/60000 ( 43%)]  Loss: 0.237137
# Train Epoch: 28 [38400/60000 ( 64%)]  Loss: 0.292288
# Train Epoch: 28 [51200/60000 ( 85%)]  Loss: 0.446329
# Test set: Average loss: 0.0021, Accuracy: 54501/60000 (90.83%)
# Test set: Average loss: 0.0032, Accuracy: 8933/10000 (89.33%)
# Train Epoch: 29 [    0/60000 (  0%)]  Loss: 0.237199
# Train Epoch: 29 [12800/60000 ( 21%)]  Loss: 0.218383
# Train Epoch: 29 [25600/60000 ( 43%)]  Loss: 0.231215
# Train Epoch: 29 [38400/60000 ( 64%)]  Loss: 0.192292
# Train Epoch: 29 [51200/60000 ( 85%)]  Loss: 0.313443
# Test set: Average loss: 0.0019, Accuracy: 54947/60000 (91.58%)
# Test set: Average loss: 0.0030, Accuracy: 8965/10000 (89.65%)
# Train Epoch: 30 [    0/60000 (  0%)]  Loss: 0.279301
# Train Epoch: 30 [12800/60000 ( 21%)]  Loss: 0.415198
# Train Epoch: 30 [25600/60000 ( 43%)]  Loss: 0.232169
# Train Epoch: 30 [38400/60000 ( 64%)]  Loss: 0.214568
# Train Epoch: 30 [51200/60000 ( 85%)]  Loss: 0.311780
# Test set: Average loss: 0.0019, Accuracy: 54976/60000 (91.63%)
# Test set: Average loss: 0.0032, Accuracy: 8917/10000 (89.17%)
# Train Epoch: 31 [    0/60000 (  0%)]  Loss: 0.313003
# Train Epoch: 31 [12800/60000 ( 21%)]  Loss: 0.223092
# Train Epoch: 31 [25600/60000 ( 43%)]  Loss: 0.153064
# Train Epoch: 31 [38400/60000 ( 64%)]  Loss: 0.266053
# Train Epoch: 31 [51200/60000 ( 85%)]  Loss: 0.229208
# Test set: Average loss: 0.0019, Accuracy: 54920/60000 (91.53%)
# Test set: Average loss: 0.0029, Accuracy: 9034/10000 (90.34%)
# Train Epoch: 32 [    0/60000 (  0%)]  Loss: 0.137104
# Train Epoch: 32 [12800/60000 ( 21%)]  Loss: 0.271034
# Train Epoch: 32 [25600/60000 ( 43%)]  Loss: 0.336296
# Train Epoch: 32 [38400/60000 ( 64%)]  Loss: 0.263852
# Train Epoch: 32 [51200/60000 ( 85%)]  Loss: 0.294927
# Test set: Average loss: 0.0019, Accuracy: 54995/60000 (91.66%)
# Test set: Average loss: 0.0026, Accuracy: 9128/10000 (91.28%)
# Train Epoch: 33 [    0/60000 (  0%)]  Loss: 0.229962
# Train Epoch: 33 [12800/60000 ( 21%)]  Loss: 0.244311
# Train Epoch: 33 [25600/60000 ( 43%)]  Loss: 0.233936
# Train Epoch: 33 [38400/60000 ( 64%)]  Loss: 0.206025
# Train Epoch: 33 [51200/60000 ( 85%)]  Loss: 0.277560
# Test set: Average loss: 0.0016, Accuracy: 55760/60000 (92.93%)
# Test set: Average loss: 0.0026, Accuracy: 9144/10000 (91.44%)
# Train Epoch: 34 [    0/60000 (  0%)]  Loss: 0.179388
# Train Epoch: 34 [12800/60000 ( 21%)]  Loss: 0.212287
# Train Epoch: 34 [25600/60000 ( 43%)]  Loss: 0.342794
# Train Epoch: 34 [38400/60000 ( 64%)]  Loss: 0.291786
# Train Epoch: 34 [51200/60000 ( 85%)]  Loss: 0.451237
# Test set: Average loss: 0.0018, Accuracy: 55253/60000 (92.09%)
# Test set: Average loss: 0.0029, Accuracy: 9034/10000 (90.34%)
# Train Epoch: 35 [    0/60000 (  0%)]  Loss: 0.208219
# Train Epoch: 35 [12800/60000 ( 21%)]  Loss: 0.171892
# Train Epoch: 35 [25600/60000 ( 43%)]  Loss: 0.221436
# Train Epoch: 35 [38400/60000 ( 64%)]  Loss: 0.276139
# Train Epoch: 35 [51200/60000 ( 85%)]  Loss: 0.192615
# Test set: Average loss: 0.0016, Accuracy: 55820/60000 (93.03%)
# Test set: Average loss: 0.0025, Accuracy: 9176/10000 (91.76%)
# Train Epoch: 36 [    0/60000 (  0%)]  Loss: 0.200878
# Train Epoch: 36 [12800/60000 ( 21%)]  Loss: 0.202594
# Train Epoch: 36 [25600/60000 ( 43%)]  Loss: 0.214812
# Train Epoch: 36 [38400/60000 ( 64%)]  Loss: 0.196204
# Train Epoch: 36 [51200/60000 ( 85%)]  Loss: 0.188124
# Test set: Average loss: 0.0016, Accuracy: 55738/60000 (92.90%)
# Test set: Average loss: 0.0026, Accuracy: 9131/10000 (91.31%)
# Train Epoch: 37 [    0/60000 (  0%)]  Loss: 0.276534
# Train Epoch: 37 [12800/60000 ( 21%)]  Loss: 0.191409
# Train Epoch: 37 [25600/60000 ( 43%)]  Loss: 0.300831
# Train Epoch: 37 [38400/60000 ( 64%)]  Loss: 0.231607
# Train Epoch: 37 [51200/60000 ( 85%)]  Loss: 0.153577
# Test set: Average loss: 0.0016, Accuracy: 55684/60000 (92.81%)
# Test set: Average loss: 0.0026, Accuracy: 9134/10000 (91.34%)
# Train Epoch: 38 [    0/60000 (  0%)]  Loss: 0.254122
# Train Epoch: 38 [12800/60000 ( 21%)]  Loss: 0.152324
# Train Epoch: 38 [25600/60000 ( 43%)]  Loss: 0.212651
# Train Epoch: 38 [38400/60000 ( 64%)]  Loss: 0.283103
# Train Epoch: 38 [51200/60000 ( 85%)]  Loss: 0.190127
# Test set: Average loss: 0.0014, Accuracy: 56367/60000 (93.94%)
# Test set: Average loss: 0.0024, Accuracy: 9222/10000 (92.22%)
# Train Epoch: 39 [    0/60000 (  0%)]  Loss: 0.150718
# Train Epoch: 39 [12800/60000 ( 21%)]  Loss: 0.228046
# Train Epoch: 39 [25600/60000 ( 43%)]  Loss: 0.144295
# Train Epoch: 39 [38400/60000 ( 64%)]  Loss: 0.107402
# Train Epoch: 39 [51200/60000 ( 85%)]  Loss: 0.204302
# Test set: Average loss: 0.0014, Accuracy: 56441/60000 (94.07%)
# Test set: Average loss: 0.0022, Accuracy: 9271/10000 (92.71%)
# Train Epoch: 40 [    0/60000 (  0%)]  Loss: 0.218647
# Train Epoch: 40 [12800/60000 ( 21%)]  Loss: 0.162225
# Train Epoch: 40 [25600/60000 ( 43%)]  Loss: 0.163285
# Train Epoch: 40 [38400/60000 ( 64%)]  Loss: 0.157848
# Train Epoch: 40 [51200/60000 ( 85%)]  Loss: 0.160264
# Test set: Average loss: 0.0014, Accuracy: 56407/60000 (94.01%)
# Test set: Average loss: 0.0023, Accuracy: 9228/10000 (92.28%)
# Train Epoch: 41 [    0/60000 (  0%)]  Loss: 0.110068
# Train Epoch: 41 [12800/60000 ( 21%)]  Loss: 0.127137
# Train Epoch: 41 [25600/60000 ( 43%)]  Loss: 0.157977
# Train Epoch: 41 [38400/60000 ( 64%)]  Loss: 0.274536
# Train Epoch: 41 [51200/60000 ( 85%)]  Loss: 0.188675
# Test set: Average loss: 0.0014, Accuracy: 56126/60000 (93.54%)
# Test set: Average loss: 0.0024, Accuracy: 9233/10000 (92.33%)
# Train Epoch: 42 [    0/60000 (  0%)]  Loss: 0.212237
# Train Epoch: 42 [12800/60000 ( 21%)]  Loss: 0.083764
# Train Epoch: 42 [25600/60000 ( 43%)]  Loss: 0.217964
# Train Epoch: 42 [38400/60000 ( 64%)]  Loss: 0.118900
# Train Epoch: 42 [51200/60000 ( 85%)]  Loss: 0.182208
# Test set: Average loss: 0.0014, Accuracy: 56466/60000 (94.11%)
# Test set: Average loss: 0.0023, Accuracy: 9266/10000 (92.66%)
# Train Epoch: 43 [    0/60000 (  0%)]  Loss: 0.174266
# Train Epoch: 43 [12800/60000 ( 21%)]  Loss: 0.095512
# Train Epoch: 43 [25600/60000 ( 43%)]  Loss: 0.281211
# Train Epoch: 43 [38400/60000 ( 64%)]  Loss: 0.166928
# Train Epoch: 43 [51200/60000 ( 85%)]  Loss: 0.191108
# Test set: Average loss: 0.0011, Accuracy: 57187/60000 (95.31%)
# Test set: Average loss: 0.0018, Accuracy: 9410/10000 (94.10%)
# Train Epoch: 44 [    0/60000 (  0%)]  Loss: 0.121126
# Train Epoch: 44 [12800/60000 ( 21%)]  Loss: 0.170524
# Train Epoch: 44 [25600/60000 ( 43%)]  Loss: 0.112309
# Train Epoch: 44 [38400/60000 ( 64%)]  Loss: 0.260491
# Train Epoch: 44 [51200/60000 ( 85%)]  Loss: 0.145010
# Test set: Average loss: 0.0012, Accuracy: 56909/60000 (94.85%)
# Test set: Average loss: 0.0021, Accuracy: 9319/10000 (93.19%)
# Train Epoch: 45 [    0/60000 (  0%)]  Loss: 0.165403
# Train Epoch: 45 [12800/60000 ( 21%)]  Loss: 0.152582
# Train Epoch: 45 [25600/60000 ( 43%)]  Loss: 0.106191
# Train Epoch: 45 [38400/60000 ( 64%)]  Loss: 0.294611
# Train Epoch: 45 [51200/60000 ( 85%)]  Loss: 0.152870
# Test set: Average loss: 0.0012, Accuracy: 56973/60000 (94.95%)
# Test set: Average loss: 0.0022, Accuracy: 9277/10000 (92.77%)
# Train Epoch: 46 [    0/60000 (  0%)]  Loss: 0.196485
# Train Epoch: 46 [12800/60000 ( 21%)]  Loss: 0.104847
# Train Epoch: 46 [25600/60000 ( 43%)]  Loss: 0.170618
# Train Epoch: 46 [38400/60000 ( 64%)]  Loss: 0.109499
# Train Epoch: 46 [51200/60000 ( 85%)]  Loss: 0.163612
# Test set: Average loss: 0.0011, Accuracy: 57036/60000 (95.06%)
# Test set: Average loss: 0.0020, Accuracy: 9339/10000 (93.39%)
# Train Epoch: 47 [    0/60000 (  0%)]  Loss: 0.094640
# Train Epoch: 47 [12800/60000 ( 21%)]  Loss: 0.278439
# Train Epoch: 47 [25600/60000 ( 43%)]  Loss: 0.251496
# Train Epoch: 47 [38400/60000 ( 64%)]  Loss: 0.146415
# Train Epoch: 47 [51200/60000 ( 85%)]  Loss: 0.149777
# Test set: Average loss: 0.0012, Accuracy: 56866/60000 (94.78%)
# Test set: Average loss: 0.0023, Accuracy: 9265/10000 (92.65%)
# Train Epoch: 48 [    0/60000 (  0%)]  Loss: 0.183306
# Train Epoch: 48 [12800/60000 ( 21%)]  Loss: 0.079350
# Train Epoch: 48 [25600/60000 ( 43%)]  Loss: 0.140941
# Train Epoch: 48 [38400/60000 ( 64%)]  Loss: 0.212588
# Train Epoch: 48 [51200/60000 ( 85%)]  Loss: 0.201078
# Test set: Average loss: 0.0010, Accuracy: 57262/60000 (95.44%)
# Test set: Average loss: 0.0019, Accuracy: 9398/10000 (93.98%)
# Train Epoch: 49 [    0/60000 (  0%)]  Loss: 0.158810
# Train Epoch: 49 [12800/60000 ( 21%)]  Loss: 0.228547
# Train Epoch: 49 [25600/60000 ( 43%)]  Loss: 0.155030
# Train Epoch: 49 [38400/60000 ( 64%)]  Loss: 0.119639
# Train Epoch: 49 [51200/60000 ( 85%)]  Loss: 0.195276
# Test set: Average loss: 0.0011, Accuracy: 56990/60000 (94.98%)
# Test set: Average loss: 0.0023, Accuracy: 9247/10000 (92.47%)
# Test set: Average loss: 0.0011, Accuracy: 56996/60000 (94.99%)
# Test set: Average loss: 0.0023, Accuracy: 9247/10000 (92.47%)
# 92.47

# %%
def softmax_by_row(logits, T = 1.0):
    mx = np.max(logits, axis=-1, keepdims=True)
    exp = np.exp((logits - mx)/T)
    denominator = np.sum(exp, axis=-1, keepdims=True)
    return exp/denominator

def classifier_performance(model, train_loader, test_loader):

    output_train_benign = []
    train_label = []
    for num, data in enumerate(train_loader):
        images,labels = data
        image_tensor= images.to(device)
        img_variable = Variable(image_tensor, requires_grad=True)
        output = model.forward(img_variable)

        train_label.append(labels.numpy())
        logits = output.logits
        output_train_benign.append(softmax_by_row(logits.cpu().detach().numpy(),T = 1))


    train_label = np.concatenate(train_label)
    output_train_benign=np.concatenate(output_train_benign)

    test_label = []
    output_test_benign = []

    for num, data in enumerate(test_loader):
        images,labels = data

        image_tensor= images.to(device)
        img_variable = Variable(image_tensor, requires_grad=True)

        output = model.forward(img_variable)

        test_label.append(labels.numpy())
        logits = output.logits
        output_test_benign.append(softmax_by_row(logits.cpu().detach().numpy(),T = 1))


    test_label = np.concatenate(test_label)
    output_test_benign=np.concatenate(output_test_benign)


    train_acc1 = np.sum(np.argmax(output_train_benign,axis=1) == train_label.flatten())/len(train_label)
    test_acc1 = np.sum(np.argmax(output_test_benign,axis=1) == test_label.flatten())/len(test_label)

    print('Accuracy: ', (train_acc1, test_acc1))

    return output_train_benign, output_test_benign, train_label, test_label




def inference_via_confidence(confidence_mtx1, confidence_mtx2, label_vec1, label_vec2):
    
    #----------------First step: obtain confidence lists for both training dataset and test dataset--------------
    confidence1 = []
    confidence2 = []
    acc1 = 0
    acc2 = 0
    for num in range(confidence_mtx1.shape[0]):
        confidence1.append(confidence_mtx1[num,label_vec1[num]])
        if np.argmax(confidence_mtx1[num,:]) == label_vec1[num]:
            acc1 += 1
            
    for num in range(confidence_mtx2.shape[0]):
        confidence2.append(confidence_mtx2[num,label_vec2[num]])
        if np.argmax(confidence_mtx2[num,:]) == label_vec2[num]:
            acc2 += 1
    confidence1 = np.array(confidence1)
    confidence2 = np.array(confidence2)
    
    print('model accuracy for training and test-', (acc1/confidence_mtx1.shape[0], acc2/confidence_mtx2.shape[0]) )
    
    
    #sort_confidence = np.sort(confidence1)
    sort_confidence = np.sort(np.concatenate((confidence1, confidence2)))
    max_accuracy = 0.5
    best_precision = 0.5
    best_recall = 0.5
    for num in range(len(sort_confidence)):
        delta = sort_confidence[num]
        ratio1 = np.sum(confidence1>=delta)/confidence_mtx1.shape[0]
        ratio2 = np.sum(confidence2>=delta)/confidence_mtx2.shape[0]
        accuracy_now = 0.5*(ratio1+1-ratio2)
        if accuracy_now > max_accuracy:
            max_accuracy = accuracy_now
            best_precision = ratio1/(ratio1+ratio2)
            best_recall = ratio1
    print('membership inference accuracy is:', max_accuracy)
    return max_accuracy

# %%
from torch.autograd import Variable
import os
import numpy as np
import math 
import scipy
import sys  

output_train, output_test, train_label, test_label = classifier_performance(model, trainloader, testloader)
inference_accuracy=inference_via_confidence(output_train, output_test, train_label, test_label)
print("Maximum Accuracy:",inference_accuracy)
# Out:
# Accuracy:  (0.9493, 0.9247)
# model accuracy for training and test- (0.9493, 0.9247)
# membership inference accuracy is: 0.51555
# Maximum Accuracy: 0.51555
